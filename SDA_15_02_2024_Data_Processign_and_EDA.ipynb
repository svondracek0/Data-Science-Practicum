# %% [markdown]
# <a href="https://colab.research.google.com/github/svondracek0/Data-Science-Practicum/blob/main/SDA_15_02_2024_Data_Processign_and_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Processing Opakování

# %% [markdown]
# V tomto notebooku naleznete materiály, se kterými jsme opakovali data processing pomocí knihovny pandas.
#
# ## Načtení a představení dat

# %%
# import knihovny
import pandas as pd

# %%
# Načtení dat
df_housing = pd.read_csv("https://raw.githubusercontent.com/melindaleung/Ames-Iowa-Housing-Dataset/refs/heads/master/data/ames%20iowa%20housing.csv")

# %%
# Sloupce nasi tabulky
df_housing.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# Naším cílen není konstruovat ML model, ale pouze si ukázat základní operace které můžeme vykonávat nad pd.DataFrame objektem. K ilustraci s izobrazíme proměnnou SalePrice, na které si transformace ukážeme.

# %%
import plotly.express as px
fig = px.histogram(df_housing['SalePrice'], nbins=60)
fig.show(title="Cena nemovitosti v Iowa - Ames")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bae8f287-1c29-441f-9934-7a77d5f4f294" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bae8f287-1c29-441f-9934-7a77d5f4f294")) {                    Plotly.newPlot(                        "bae8f287-1c29-441f-9934-7a77d5f4f294",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=SalePrice\u003cbr\u003evalue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SalePrice","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"SalePrice","nbinsx":60,"offsetgroup":"SalePrice","orientation":"v","showlegend":true,"x":[208500,181500,223500,140000,250000,143000,307000,200000,129900,118000,129500,345000,144000,279500,157000,132000,149000,90000,159000,139000,325300,139400,230000,129900,154000,256300,134800,306000,207500,68500,40000,149350,179900,165500,277500,309000,145000,153000,109000,82000,160000,170000,144000,130250,141000,319900,239686,249700,113000,127000,177000,114500,110000,385000,130000,180500,172500,196500,438780,124900,158000,101000,202500,140000,219500,317000,180000,226000,80000,225000,244000,129500,185000,144900,107400,91000,135750,127000,136500,110000,193500,153500,245000,126500,168500,260000,174000,164500,85000,123600,109900,98600,163500,133900,204750,185000,214000,94750,83000,128950,205000,178000,118964,198900,169500,250000,100000,115000,115000,190000,136900,180000,383970,217000,259500,176000,139000,155000,320000,163990,180000,100000,136000,153900,181000,84500,128000,87000,155000,150000,226000,244000,150750,220000,180000,174000,143000,171000,230000,231500,115000,260000,166000,204000,125000,130000,105000,222500,141000,115000,122000,372402,190000,235000,125000,79000,109500,269500,254900,320000,162500,412500,220000,103200,152000,127500,190000,325624,183500,228000,128500,215000,239000,163000,184000,243000,211000,172500,501837,100000,177000,200100,120000,200000,127000,475000,173000,135000,153337,286000,315000,184000,192000,130000,127000,148500,311872,235000,104000,274900,140000,171500,112000,149000,110000,180500,143900,141000,277000,145000,98000,186000,252678,156000,161750,134450,210000,107000,311500,167240,204900,200000,179900,97000,386250,112000,290000,106000,125000,192500,148000,403000,94500,128200,216500,89500,185500,194500,318000,113000,262500,110500,79000,120000,205000,241500,137000,140000,180000,277000,76500,235000,173000,158000,145000,230000,207500,220000,231500,97000,176000,276000,151000,130000,73000,175500,185000,179500,120500,148000,266000,241500,290000,139000,124500,205000,201000,141000,415298,192000,228500,185000,207500,244600,179200,164700,159000,88000,122000,153575,233230,135900,131000,235000,167000,142500,152000,239000,175000,158500,157000,267000,205000,149900,295000,305900,225000,89500,82500,360000,165600,132000,119900,375000,178000,188500,260000,270000,260000,187500,342643,354000,301000,126175,242000,87000,324000,145250,214500,78000,119000,139000,284000,207000,192000,228950,377426,214000,202500,155000,202900,82000,87500,266000,85000,140200,151500,157500,154000,437154,318061,190000,95000,105900,140000,177500,173000,134000,130000,280000,156000,145000,198500,118000,190000,147000,159000,165000,132000,162000,172400,134432,125000,123000,219500,61000,148000,340000,394432,179000,127000,187750,213500,76000,240000,192000,81000,125000,191000,426000,119000,215000,106500,100000,109000,129000,123000,169500,67000,241000,245500,164990,108000,258000,168000,150000,115000,177000,280000,339750,60000,145000,222000,115000,228000,181134,149500,239000,126000,142000,206300,215000,113000,315000,139000,135000,275000,109008,195400,175000,85400,79900,122500,181000,81000,212000,116000,119000,90350,110000,555000,118000,162900,172500,210000,127500,190000,19990 ...

# %% [markdown]
# ## Datové transformace
#
# Vidíme, že proměnná je pozitivně sešikmená. V takovém případě se někdy hodí provést tzv. logaritmickou transformaci, kterou data log-**normalizujeme**

# %%
import numpy as np

# %%
import plotly.express as px
fig = px.histogram(np.log(df_housing['SalePrice']), nbins=60)
fig.show(title="Cena nemovitosti v Iowa - Ames")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c40e8b1b-f373-4292-9fcc-0ed9033c1cf2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c40e8b1b-f373-4292-9fcc-0ed9033c1cf2")) {                    Plotly.newPlot(                        "c40e8b1b-f373-4292-9fcc-0ed9033c1cf2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=SalePrice\u003cbr\u003evalue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SalePrice","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"SalePrice","nbinsx":60,"offsetgroup":"SalePrice","orientation":"v","showlegend":true,"x":[12.247694320220994,12.109010932687042,12.31716669303576,11.84939770159144,12.429216196844383,11.870599909242044,12.634603026569334,12.206072645530174,11.77452020265869,11.678439903447801,11.771436160121729,12.751299696013497,11.877568578558138,12.540757571577291,11.964001084330445,11.790557201568507,11.911701584927597,11.407564949312402,11.976659481202368,11.842229212112828,12.692503112461443,11.845102777308561,12.345834587905333,11.77452020265869,11.944707881395766
# GarageFinish    0.055479
# GarageQual      0.055479
# BsmtFinType2    0.026027
# BsmtExposure    0.026027
# BsmtQual        0.025342
# dtype: float64

# %% [markdown]
# Některé sloupce označují velmi vysoké množství chybějících hodnot. Nastavíme tedy lit podílu chyvějcíích hodnot a takové sloupce odstraníme.

# %%
threshold = 0.7

# %%
df_new = df_housing[df_housing.columns[df_housing.isnull().mean() < threshold]]

# %%
df_new.isna().mean().sort_values(ascending=False).head(15)
# Out:
# MasVnrType      0.597260
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageCond      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageType      0.055479
# BsmtFinType2    0.026027
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtCond        0.025342
# BsmtQual        0.025342
# MasVnrArea      0.005479
# Electrical      0.000685
# dtype: float64

# %% [markdown]
# Některé operace jous závislé na datovém typy. V následijící části si ukážeme, jak datové typy vyfiltrovat

# %%
numeric_vars = df_housing.apply(lambda x: pd.api.types.is_numeric_dtype(x))

# %%
df_categorical = df_housing.loc[:, ~numeric_vars]

# %% [markdown]
# Nejčetnější odnotu si zobrazíme následujícím způsobem

# %%
df_categorical['MSZoning'].value_counts().idxmax()
# Out:
# 'RL'

# %%
df_categorical.iloc[:, :5].value_counts()
# Out:
# MSZoning  Street  Alley  LotShape  LandContour
# RM        Pave    Grvl   Reg       Lvl            28
# FV        Pave    Pave   Reg       Lvl            18
# RL        Pave    Grvl   Reg       Lvl            11
# RM        Pave    Pave   Reg       Lvl             5
# FV        Pave    Pave   IR1       Lvl             5
# RL        Pave    Pave   Reg       Lvl             4
# RM        Pave    Grvl   Reg       Bnk             3
#                          IR1       Lvl             2
# RL        Pave    Grvl   Reg       Bnk             2
# RM        Pave    Pave   Reg       Bnk             1
#                          IR1       Lvl             1
#                   Grvl   Reg       HLS             1
#                          IR3       Bnk             1
# C (all)   Pave    Pave   Reg       HLS             1
# RM        Pave    Grvl   IR1       Bnk             1
# C (all)   Pave    Pave   Reg       Lvl             1
# RL        Pave    Pave   IR1       Bnk             1
#                   Grvl   IR1       HLS             1
# RH        Pave    Pave   Reg       Bnk             1
#                          IR2       Bnk             1
# FV        Pave    Pave   IR2       Lvl             1
# RL        Pave    Pave   Reg       Bnk             1
# Name: count, dtype: int64

# %% [markdown]
# Na numerických daových typech můžeme zobrazit popisné statistiky:

# %%
df_housing.loc[:, numeric_vars].median()
# Out:
# Id                  730.5
# MSSubClass           50.0
# LotFrontage          69.0
# LotArea            9478.5
# OverallQual           6.0
# OverallCond           5.0
# YearBuilt          1973.0
# YearRemodAdd       1994.0
# MasVnrArea            0.0
# BsmtFinSF1          383.5
# BsmtFinSF2            0.0
# BsmtUnfSF           477.5
# TotalBsmtSF         991.5
# 1stFlrSF           1087.0
# 2ndFlrSF              0.0
# LowQualFinSF          0.0
# GrLivArea          1464.0
# BsmtFullBath          0.0
# BsmtHalfBath          0.0
# FullBath              2.0
# HalfBath              0.0
# BedroomAbvGr          3.0
# KitchenAbvGr          1.0
# TotRmsAbvGrd          6.0
# Fireplaces            1.0
# GarageYrBlt        1980.0
# GarageCars            2.0
# GarageArea          480.0
# WoodDeckSF            0.0
# OpenPorchSF          25.0
# EnclosedPorch         0.0
# 3SsnPorch             0.0
# ScreenPorch           0.0
# PoolArea              0.0
# MiscVal               0.0
# MoSold                6.0
# YrSold             2008.0
# SalePrice        163000.0
# dtype: float64

# %% [markdown]
# ## Odlehlé hodnoty a agregační funkce
#
# Dalším ze způsobů filtrování datového souboru je detekce odlehlých hodnot.
# Odlehlé hodnoty můžeme identifikovat mj. skrze kvantily standardizovaného normálního rozdělení:

# %%
upper_lim = df_housing['SalePrice'].mean() + df_housing['SalePrice'].std() * 3

# %%
upper_lim
# Out:
# 419248.70453907084

# %%
df_high_price = df_housing.loc[df_housing['SalePrice'] > upper_lim, :]

# %%
df_high_price.loc[df_high_price['SalePrice'] < upper_lim, :]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 81 columns]

# %% [markdown]
# Další z často užívaných transformzcí je tzv. Dummy, nebo One-hot encoding, kterým jsme schopni převést kategorické proměnné na numerické.

# %%
df_housing['MSZoning'].sample(15, random_state=42)
# Out:
# 892          RL
# 1105         RL
# 413          RM
# 522          RM
# 1036         RL
# 614          RM
# 218          RL
# 1160         RL
# 649          RM
# 887          RL
# 576          RL
# 1252         RL
# 1061    C (all)
# 567          RL
# 1108         RL
# Name: MSZoning, dtype: object

# %%
pd.get_dummies(df_housing['MSZoning'].sample(15, random_state=42))
# Out:
#       C (all)     RL     RM
# 892     False   True  False
# 1105    False   True  False
# 413     False  False   True
# 522     False  False   True
# 1036    False   True  False
# 614     False  False   True
# 218     False   True  False
# 1160    False   True  False
# 649     False  False   True
# 887     False   True  False
# 576     False   True  False
# 1252    False   True  False
# 1061     True  False  False
# 567     False   True  False
# 1108    False   True  False

# %% [markdown]
# Č

# %%
df_housing['SalePrice'].mean()
# Out:
# 180921.19589041095

# %%
df_housing.loc[:, ['MSZoning', 'SalePrice']].groupby(['MSZoning']).mean()
# Out:
#               SalePrice
# MSZoning
# C (all)    74528.000000
# FV        214014.061538
# RH        131558.375000
# RL        191004.994787
# RM        126316.830275

# %% [markdown]
# ## Škálování dat
#
# Pro některé algoritmy strojového učení je vhodné mít data převedená na stejou škálu. Jak škálování provádět se podíváme v této části

# %%
df_scaled = df_housing.loc[:, ['YearBuilt', 'SalePrice']]

# %%
px.histogram(df_scaled.melt(), facet_row='variable')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cf6e0d0b-e997-468b-a845-299b4a0aa39a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf6e0d0b-e997-468b-a845-299b4a0aa39a")) {                    Plotly.newPlot(                        "cf6e0d0b-e997-468b-a845-299b4a0aa39a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"_variable=value\u003cbr\u003evariable=YearBuilt\u003cbr\u003e_value=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"value","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"value","offsetgroup":"value","orientation":"v","showlegend":true,"x":[2003,1976,2001,1915,2000,1993,2004,1973,1931,1939,1965,2005,1962,2006,1960,1929,1970,1967,2004,1958,2005,1930,2002,1976,1968,2007,1951,2007,1957,1927,1920,1966,2007,1959,2005,2004,1994,1954,1953,1955,1965,1959,1983,1975,1959,2005,2003,2006,1920,1966,1997,1934,1963,1981,1955,1964,1999,2004,2006,1972,2004,1920,2006,1921,1997,2004,1970,2003,1945,1953,1973,1982,1998,1954,1915,1973,1956,1948,1968,1910,1968,1998,2007,1960,1995,1991,2005,2009,1915,1994
1172352761668802,-0.07511149463722075,-1.0687338036406382,-0.4394396746051405,0.7197863525655132,0.25609594169725175,-1.2012167781744272,0.15673371079690998,-1.3668204963416635,-0.1744737255375625,-0.4394396746051405,-0.1744737255375625,0.9516315579996439,-0.40631893097169325,0.9847523016330911,-0.108232238270668,-0.04199075100377351,-0.14135298190411524,0.554182634398277,0.9185108143661966,0.8522693270993021,-0.008870007370326258,1.1172352761668802,-0.6381641364058239,0.9185108143661966,-0.27383595643790426,1.084114532533433,-1.3336997527082162,0.9847523016330911,1.084114532533433,-1.1680960345409799,0.12361296716346273,1.1834767634337746,-0.008870007370326258,-0.373198187338246,-1.5986657017757941,-1.5655449581423468,-0.7044056236727184,1.24 ...

# %% [markdown]
# Vidíme, že nyní jsou obě proměnné převedeny na stejnou škálu. Rozdíl mezi MinMax škáluje mezi minimální a maximální hodnoutu - hodnoty jsou tedy omezené. Oproti tomu StandardScaler škáluje podle hodnot standardizovaného normálního rozložení, které není omezeno.

# %% [markdown]
# ## Práce s datumem
#
# V této části si připomeneme, jak pracovat s daumem pomocí datetime modulu

# %%
jmeno = "Stepan Vondracek"

# %%
# pripomente si jak rozdelit string
jmeno.split(" ")
# Out:
# ['Stepan', 'Vondracek']

# %%
# vytvorte tabulku se jmeny
df_names = pd.DataFrame({"jmeno": ["Stepan Vondracek", "Karel Novotny"]})
df_names
# Out:
#               jmeno
# 0  Stepan Vondracek
# 1     Karel Novotny

# %%
# chceme vybrat pouze vsechna krestni jmena - ta jsou v ramci stringu oddelena
# pomoci mezery. VYbirame tedy ty casti stringu pred mezerou
df_names['krestni'] = df_names['jmeno'].str.split(" ").apply(lambda x: x[0])

# %%
df_names
# Out:
#               jmeno krestni
# 0  Stepan Vondracek  Stepan
# 1     Karel Novotny   Karel

# %%
# Vytvorime tabulku s datumem

from datetime import date
data = pd.DataFrame({'date':
['01-01-2017',
'04-12-2008',
'23-06-1988',
'25-08-1999',
'20-02-1993',
]})

# %%
# podobne jako v predchozi casti muzeme extrahovat rok, ale je to nejlepsi zpusob?
data['year'] = data['date'].str.split("-").apply(lambda x: x[-1])

# %%
# datovy typ je object coz odpovida typu string
data.dtypes
# Out:
# date    object
# year    object
# dtype: object

# %%
# prevedeme datum na datetime format
data['date'] = pd.to_datetime(data['date'], format="%d-%m-%Y")
data
# Out:
#         date  year
# 0 2017-01-01  2017
# 1 2008-12-04  2008
# 2 1988-06-23  1988
# 3 1999-08-25  1999
# 4 1993-02-20  1993

# %%
# jiny zpusob extrakce roku za pouziti datetime typu
data['date'].dt.year
# Out:
# 0    2017
# 1    2008
# 2    1988
# 3    1999
# 4    1993
# Name: date, dtype: int32

# %%
from datetime import date
date_now = date.today()
date_now
# Out:
# datetime.date(2025, 2, 18)

# %%
# s daty muzeme delat ruzne numericke operace, jako napriklad takhle spocitat dobu ktera uplynula dodnes od daneho data
date_now = pd.to_datetime('now')
data['years_passed_from_now'] = (date_now - data['date']).dt.days // 365

# %%
data
# Out:
#         date  year  years_passed_from_now
# 0 2017-01-01  2017                      8
# 1 2008-12-04  2008                     16
# 2 1988-06-23  1988                     36
# 3 1999-08-25  1999                     25
# 4 1993-02-20  1993                     32
