# %% [markdown]
# <a href="https://colab.research.google.com/github/svondracek0/Data-Science-Practicum/blob/main/Data_Science_SDA_16_02_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SDA Dataova Analyza 16-02-2025

# %% [markdown]
# ## SQLAlchemy

# %%
# !pip install sqlalchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 31.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 kB 30.9 MB/s eta 0:00:00
# ...

# %%
import sqlalchemy
from sqlalchemy import create_engine

# %%
# nainstaluje mysql server a PymySQL
# !apt-get install mysql-server > /dev/null
# !service mysql start
# !mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'root'"
# !pip -q install PyMySQL
# Out:
#  * Starting MySQL database server mysqld
# su: warning: cannot change directory to /nonexistent: No such file or directory
#    ...done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.7 MB/s eta 0:00:00

# %%
from sqlalchemy import create_engine
from sqlalchemy import text
# Create the SQLAlchemy engine
engine = create_engine("mysql+pymysql://root:root@localhost/", echo=True)

# Create a connection from the engine
with engine.connect() as connection:
    # Execute the SQL statements
    connection.execute(text("CREATE DATABASE car_rental;"))  # Create the database
# Out:
# 2025-02-18 13:43:30,845 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# INFO:sqlalchemy.engine.Engine:SELECT DATABASE()
# 2025-02-18 13:43:30,847 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:43:30,850 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# INFO:sqlalchemy.engine.Engine:SELECT @@sql_mode
# 2025-02-18 13:43:30,852 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:43:30,855 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# INFO:sqlalchemy.engine.Engine:SELECT @@lower_case_table_names
# 2025-02-18 13:43:30,856 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:43:30,860 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:43:30,861 INFO sqlalchemy.engine.Engine CREATE DATABASE car_rental;
# ...

# %%
from sqlalchemy.orm import declarative_base

# %%
engine_db_cars = create_engine("mysql+pymysql://root:root@localhost/car_rental", echo=True)
base = declarative_base()

# %% [markdown]
# ### Úkol 6
# 1. Vytvořte pomocí SQLAlchemy auta, zákazníky a rezervace na
# základě instrukcí níže (bez vztahů):
# - a. auta: car_id (int, pk), producer (str), model (str), year (int), horse_power (int), price_per_day (int)
# - b. zákazníci: client_id (int, pk), name (str), surname (str),
# address (str), city (str)
# - c. rezervace: booking_id (int, pk), client_id (int), car_id (int),
# start_date (date), end_date (date), total_amount (int)
# 2. * Vytvořte to stejné pomocí SQL dotazu.

# %%
from sqlalchemy import Column, String, Integer, Date

# %%
class Cars(base):
  __tablename__ = 'cars'

  car_id = Column(Integer, primary_key=True, autoincrement=True)
  producer = Column(String(30), nullable = False)
  model = Column(String(30), nullable=False)
  year = Column(Integer, nullable=False)
  horse_power = Column(Integer, nullable=False)
  price_per_day  = Column(Integer, nullable = False)

# %%
class Clients(base):
  __tablename__ = 'clients'
  client_id = Column(Integer, primary_key=True, autoincrement=True)
  name = Column(String(30), nullable=False)
  surname = Column(String(30), nullable=False)
  address = Column(String(30), nullable=False)
  city = Column(String(30), nullable=False)

# %%
class Bookings(base):
  __tablename__ = 'bookings'
  booking_id = Column(Integer, primary_key=True, autoincrement=True)
  client_id = Column(Integer, nullable=False)
  car_id = Column(Integer, nullable=False)
  start_date = Column(Date, nullable=False)
  end_date = Column(Date, nullable=False)
  total_amount = Column(Integer, nullable=False)

# %%
base.metadata.create_all(engine_db_cars)
# Out:
# 2025-02-18 13:43:41,754 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# INFO:sqlalchemy.engine.Engine:SELECT DATABASE()
# 2025-02-18 13:43:41,757 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:43:41,759 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# INFO:sqlalchemy.engine.Engine:SELECT @@sql_mode
# 2025-02-18 13:43:41,760 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:43:41,763 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# INFO:sqlalchemy.engine.Engine:SELECT @@lower_case_table_names
# 2025-02-18 13:43:41,764 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:43:41,767 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:43:41,769 INFO sqlalchemy.engine.Engine DESCRIBE `car_rental`.`cars`
# ...

# %%
with engine_db_cars.connect() as connection:
    # Execute the SQL statements
    res = connection.execute(text("SHOW TABLES"))  # Create the database
# Out:
# 2025-02-18 13:43:42,985 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:43:42,987 INFO sqlalchemy.engine.Engine SHOW TABLES
# INFO:sqlalchemy.engine.Engine:SHOW TABLES
# 2025-02-18 13:43:42,990 INFO sqlalchemy.engine.Engine [generated in 0.00438s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00438s] {}
# 2025-02-18 13:43:42,994 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK

# %%
list(res)
# Out:
# [('bookings',), ('cars',), ('clients',)]

# %%
query = """
CREATE TABLE cars_2 (
    id SERIAL,
    producer VARCHAR(50),
    model VARCHAR(50),
    year INT,
    horse_power INT,
    price_per_day DECIMAL
);
"""

# %%
with engine_db_cars.connect() as connection:
    # Execute the SQL statements
    connection.execute(text(query))  # Create the database
# Out:
# 2025-02-18 13:43:57,617 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:43:57,619 INFO sqlalchemy.engine.Engine
# CREATE TABLE cars_2 (
#     id SERIAL,
#     producer VARCHAR(50),
#     model VARCHAR(50),
#     year INT,
#     horse_power INT,
#     price_per_day DECIMAL
# );
# INFO:sqlalchemy.engine.Engine:
# CREATE TABLE cars_2 (
#     id SERIAL,
#     producer VARCHAR(50),
#     model VARCHAR(50),
#     year INT,
#     horse_power INT,
#     price_per_day DECIMAL
# );
# 2025-02-18 13:43:57,620 INFO sqlalchemy.engine.Engine [generated in 0.00331s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00331s] {}
# 2025-02-18 13:43:57,691 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK

# %% [markdown]
# ### Úkol 7
# 1. Do tabulky zákazníků a aut přídejte následující:
# - a. zákazníci: 'Andrew', 'Novak', 'Front Street 43', 'New York’
# - b. auta: 'Seat', 'Leon', 2016, 80, 200
# 2. * Doplňte vlastní data.
# 3. * Přidejte s využitím SQL:
# - a. 'Andrew', 'Jones, 'Back Street 43', Los Angeles'
# - b. 'Opel', ‘Vectra’, 2010, 240, 70000000

# %%
from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine_db_cars)
session = Session()

# %%
client_novak = Clients(name="Andrew", surname="Novak", address="Front Street 43", city="New York")
client_jones = Clients(name="Andrew", surname="Jones", address="Back Street 43", city="New York")
car_seat = Cars(producer="Seat", model="Leon", year=2016, horse_power=80, price_per_day=200)

# %%
client_jones = Clients(name="Andrew", surname="Jones", address="Back Street 43", city="New York")

# %%
session.add(client_jones)

# %%
session.add(car_seat)

# %%
session.commit()
# Out:
# 2025-02-18 13:44:07,544 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:44:07,547 INFO sqlalchemy.engine.Engine INSERT INTO cars (producer, model, year, horse_power, price_per_day) VALUES (%(producer)s, %(model)s, %(year)s, %(horse_power)s, %(price_per_day)s)
# INFO:sqlalchemy.engine.Engine:INSERT INTO cars (producer, model, year, horse_power, price_per_day) VALUES (%(producer)s, %(model)s, %(year)s, %(horse_power)s, %(price_per_day)s)
# 2025-02-18 13:44:07,550 INFO sqlalchemy.engine.Engine [generated in 0.00301s] {'producer': 'Seat', 'model': 'Leon', 'year': 2016, 'horse_power': 80, 'price_per_day': 200}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00301s] {'producer': 'Seat', 'model': 'Leon', 'year': 2016, 'horse_power': 80, 'price_per_day': 200}
# 2025-02-18 13:44:07,560 INFO sqlalchemy.engine.Engine INSERT INTO clients (name, surname, address, city) VALUES (%(name)s, %(surname)s, %(address)s, %(city)s)
# ...

# %%
client_jones_exists = "SELECT * FROM clients"

# %%
with engine_db_cars.connect() as connection:
    # Execute the SQL statements
    res_exists = connection.execute(text(client_jones_exists))  # Create the database
# Out:
# 2025-02-18 13:44:10,718 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:44:10,721 INFO sqlalchemy.engine.Engine SELECT * FROM clients
# INFO:sqlalchemy.engine.Engine:SELECT * FROM clients
# 2025-02-18 13:44:10,722 INFO sqlalchemy.engine.Engine [generated in 0.00374s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00374s] {}
# 2025-02-18 13:44:10,725 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK

# %%
list(res_exists)
# Out:
# [(1, 'Andrew', 'Jones', 'Back Street 43', 'New York')]

# %%
query_insert = "INSERT INTO clients (name, surname, address, city) VALUES ('Andrew', 'Jones', 'Back Street 43', 'New York')"

# %%
with engine_db_cars.connect() as connection:
    # Execute the SQL statements
    res_exists = connection.execute(text(query_insert))
# Out:
# 2025-02-18 13:44:16,104 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:44:16,106 INFO sqlalchemy.engine.Engine INSERT INTO clients (name, surname, address, city) VALUES ('Andrew', 'Jones', 'Back Street 43', 'New York')
# INFO:sqlalchemy.engine.Engine:INSERT INTO clients (name, surname, address, city) VALUES ('Andrew', 'Jones', 'Back Street 43', 'New York')
# 2025-02-18 13:44:16,107 INFO sqlalchemy.engine.Engine [generated in 0.00309s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00309s] {}
# 2025-02-18 13:44:16,111 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK

# %%
with engine_db_cars.connect() as connection:
    # Execute the SQL statements
    res_exists = connection.execute(text("SELECT * FROM clients"))  # Create the database
# Out:
# 2025-02-18 13:44:18,921 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:44:18,922 INFO sqlalchemy.engine.Engine SELECT * FROM clients
# INFO:sqlalchemy.engine.Engine:SELECT * FROM clients
# 2025-02-18 13:44:18,924 INFO sqlalchemy.engine.Engine [cached since 8.206s ago] {}
# INFO:sqlalchemy.engine.Engine:[cached since 8.206s ago] {}
# 2025-02-18 13:44:18,928 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK

# %%
list(res_exists)
# Out:
# [(1, 'Andrew', 'Jones', 'Back Street 43', 'New York')]

# %% [markdown]
# ### Úkol 8
# 1. Zkontrolujte, zda data přidaná v předchozí úloze byla uložena v
# databázi - přidejte kód, který vypíše všechna data z tabulek
# aut a klientů.
# 2. Zkontrolujte to samé pomocí SQL dotazu.
# 3. Aktualizujte třídy Auta, Zákazníci a Rezervace, aby bylo
# zobrazení údajů pomocí funkce print () přehlednější, např. jako
# níže (zatím nemáme přidanou rezervaci):
# <Client: id=1, name=John, surname=Smith, address=Front Street 12,city=New York>
# <Car: id=1, producer=Seat, model=Leon, year=2016, horse_power=80, price_per_day=200>

# %%
for client in session.query(Clients).order_by(Clients.client_id):
  print(vars(client))
# Out:
# 2025-02-18 13:44:23,210 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:44:23,214 INFO sqlalchemy.engine.Engine SELECT clients.client_id AS clients_client_id, clients.name AS clients_name, clients.surname AS clients_surname, clients.address AS clients_address, clients.city AS clients_city
# FROM clients ORDER BY clients.client_id
# INFO:sqlalchemy.engine.Engine:SELECT clients.client_id AS clients_client_id, clients.name AS clients_name, clients.surname AS clients_surname, clients.address AS clients_address, clients.city AS clients_city
# FROM clients ORDER BY clients.client_id
# 2025-02-18 13:44:23,216 INFO sqlalchemy.engine.Engine [generated in 0.00162s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00162s] {}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7bb83829be30>, 'client_id': 1, 'address': 'Back Street 43', 'surname': 'Jones', 'name': 'Andrew', 'city': 'New York'}

# %%
for car in session.query(Cars):
  print(car.__dict__)
# Out:
# 2025-02-18 13:44:23,844 INFO sqlalchemy.engine.Engine SELECT cars.car_id AS cars_car_id, cars.producer AS cars_producer, cars.model AS cars_model, cars.year AS cars_year, cars.horse_power AS cars_horse_power, cars.price_per_day AS cars_price_per_day
# FROM cars
# INFO:sqlalchemy.engine.Engine:SELECT cars.car_id AS cars_car_id, cars.producer AS cars_producer, cars.model AS cars_model, cars.year AS cars_year, cars.horse_power AS cars_horse_power, cars.price_per_day AS cars_price_per_day
# FROM cars
# 2025-02-18 13:44:23,846 INFO sqlalchemy.engine.Engine [generated in 0.00192s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00192s] {}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7bb838103d70>, 'horse_power': 80, 'model': 'Leon', 'year': 2016, 'car_id': 1, 'producer': 'Seat', 'price_per_day': 200}

# %%
class Cars_2(base):
  __tablename__ = 'cars_2'

  car_id = Column(Integer, primary_key=True, autoincrement=True)
  producer = Column(String(30), nullable = False)
  model = Column(String(30), nullable=False)
  year = Column(Integer, nullable=False)
  horse_power = Column(Integer, nullable=False)
  price_per_day  = Column(Integer, nullable = False)

  def __repr__(self):
    return f"""
    <Car:
    id = {self.car_id}
    producer = {self.producer}
    model = {self.model}
    year = {self.year}
    horse_power = {self.horse_power}
    price_per_day = {self.price_per_day}
    """

# %%
car_skoda = Cars_2(producer="Skoda", model="Fabia", year=2008, horse_power=80, price_per_day=100)

# %%
session.add(car_skoda)

# %%
session.commit()
# Out:
# 2025-02-18 13:44:44,725 INFO sqlalchemy.engine.Engine INSERT INTO cars_2 (producer, model, year, horse_power, price_per_day) VALUES (%(producer)s, %(model)s, %(year)s, %(horse_power)s, %(price_per_day)s)
# INFO:sqlalchemy.engine.Engine:INSERT INTO cars_2 (producer, model, year, horse_power, price_per_day) VALUES (%(producer)s, %(model)s, %(year)s, %(horse_power)s, %(price_per_day)s)
# 2025-02-18 13:44:44,727 INFO sqlalchemy.engine.Engine [generated in 0.00191s] {'producer': 'Skoda', 'model': 'Fabia', 'year': 2008, 'horse_power': 80, 'price_per_day': 100}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00191s] {'producer': 'Skoda', 'model': 'Fabia', 'year': 2008, 'horse_power': 80, 'price_per_day': 100}
# 2025-02-18 13:44:44,731 INFO sqlalchemy.engine.Engine COMMIT
# INFO:sqlalchemy.engine.Engine:COMMIT

# %% [markdown]
# ### **Úkol** 9
# 1. Potřebujeme data ke spuštění řady dotazů. Napište funkci insert_data() s argumenty:
# - a. base - základní třída modelu, jehož instanci chceme vytvořit
# - b. params - slovník se specifickými parametry vytvářeného objektu
# 2. Otestujte funkci na zadaných datech:

# %%
# napsat funkci insert data
def insert_data(session, base, params):
  session.add(base(**params))
  session.commit()

# %%
clients = [
{'name': 'Jan', 'surname': 'Kowalski', 'address': 'ul. Florianska 12', 'city': 'Krakow'},
{'name': 'Andrzej', 'surname': 'Nowak', 'address': 'ul. Saska 43', 'city': 'Wroclaw'},
{'name': 'Michal', 'surname': 'Taki', 'address': 'os. Srodkowe 12', 'city': 'Poznan'},
{'name': 'Pawel', 'surname': 'Ktory', 'address': 'ul. Stara 11', 'city': 'Gdynia'},
{'name': 'Anna', 'surname': 'Inna', 'address': 'os. Srednie 1', 'city': 'Gniezno'},
{'name': 'Alicja', 'surname': 'Panna', 'address': 'os. Duze 33', 'city': 'Torun'},
{'name': 'Damian', 'surname': 'Papa', 'address': 'ul. Skosna 66', 'city': 'Warszawa'},
{'name': 'Marek', 'surname': 'Troska', 'address': 'os. Male 90', 'city': 'Radom'},
{'name': 'Jakub', 'surname': 'Klos', 'address': 'os. Polskie 19', 'city': 'Wadowice'},
{'name': 'Lukasz', 'surname': 'Lis', 'address': 'os. Podlaskie 90', 'city': 'Bialystok'}]
cars = [
{'producer': 'Seat', 'model': 'Leon', 'year': 2016, 'horse_power': 80, 'price_per_day': 200},
{'producer': 'Toyota', 'model': 'Avensis', 'year': 2014, 'horse_power': 72, 'price_per_day': 100},
{'producer': 'Mercedes', 'model': 'CLK', 'year': 2018, 'horse_power': 190, 'price_per_day': 400},
{'producer': 'Hyundai', 'model': 'Coupe', 'year': 2014, 'horse_power': 165, 'price_per_day': 300},
{'producer': 'Dacia', 'model': 'Logan', 'year': 2015, 'horse_power': 103, 'price_per_day': 150},
{'producer': 'Saab', 'model': '95', 'year': 2012, 'horse_power': 140, 'price_per_day': 140},
{'producer': 'BMW', 'model': 'E36', 'year': 2007, 'horse_power': 110, 'price_per_day': 80},
{'producer': 'Fiat', 'model': 'Panda', 'year': 2016, 'horse_power': 77, 'price_per_day': 190},
{'producer': 'Honda', 'model': 'Civic', 'year': 2019, 'horse_power': 130, 'price_per_day': 360},
{'producer': 'Volvo', 'model': 'XC70', 'year': 2013, 'horse_power': 180, 'price_per_day': 280}]
bookings = [
{'client_id': 3, 'car_id': 3, 'start_date': '2020-07-06', 'end_date': '2020-07-08', 'total_amount': 400},
{'client_id': 6, 'car_id': 10, 'start_date': '2020-07-10', 'end_date': '2020-07-16', 'total_amount': 1680},
{'client_id': 4, 'car_id': 5, 'start_date': '2020-07-11', 'end_date': '2020-07-14', 'total_amount': 450},
{'client_id': 5, 'car_id': 4, 'start_date': '2020-07-11', 'end_date': '2020-07-13', 'total_amount': 600},
{'client_id': 7, 'car_id': 3, 'start_date': '2020-07-12', 'end_date': '2020-07-14', 'total_amount': 800},
{'client_id': 5, 'car_id': 7, 'start_date': '2020-07-14', 'end_date': '2020-07-17', 'total_amount': 240},
{'client_id': 3, 'car_id': 8, 'start_date': '2020-07-14', 'end_date': '2020-07-16', 'total_amount': 380},
{'client_id': 5, 'car_id': 9, 'start_date': '2020-07-15', 'end_date': '2020-07-18', 'total_amount': 1080},
{'client_id': 6, 'car_id': 10, 'start_date': '2020-07-16', 'end_date': '2020-07-20', 'total_amount': 1120},
{'client_id': 8, 'car_id': 1, 'start_date': '2020-07-16', 'end_date': '2020-07-19', 'total_amount': 600},
{'client_id': 9, 'car_id': 2, 'start_date': '2020-07-16', 'end_date': '2020-07-21', 'total_amount': 500},
{'client_id': 10, 'car_id': 6, 'start_date': '2020-07-17', 'end_date': '2020-07-19', 'total_amount': 280},
{'client_id': 1, 'car_id': 9, 'start_date': '2020-07-17', 'end_date': '2020-07-19', 'total_amount': 720},
{'client_id': 3, 'car_id': 7, 'start_date': '2020-07-18', 'end_date': '2020-07-21', 'total_amount': 240},
{'client_id': 5, 'car_id': 4, 'start_date': '2020-07-18', 'end_date': '2020-07-22', 'total_amount': 1200}]

# %%
for client in clients:
  insert_data(session, Clients, client)
for car in cars:
  insert_data(session, Cars, car)
for booking in bookings:
  insert_data(session, Bookings, booking)
# Out:
# 2025-02-18 13:45:58,157 INFO sqlalchemy.engine.Engine INSERT INTO clients (name, surname, address, city) VALUES (%(name)s, %(surname)s, %(address)s, %(city)s)
# INFO:sqlalchemy.engine.Engine:INSERT INTO clients (name, surname, address, city) VALUES (%(name)s, %(surname)s, %(address)s, %(city)s)
# 2025-02-18 13:45:58,159 INFO sqlalchemy.engine.Engine [cached since 110.6s ago] {'name': 'Jan', 'surname': 'Kowalski', 'address': 'ul. Florianska 12', 'city': 'Krakow'}
# INFO:sqlalchemy.engine.Engine:[cached since 110.6s ago] {'name': 'Jan', 'surname': 'Kowalski', 'address': 'ul. Florianska 12', 'city': 'Krakow'}
# 2025-02-18 13:45:58,163 INFO sqlalchemy.engine.Engine COMMIT
# INFO:sqlalchemy.engine.Engine:COMMIT
# 2025-02-18 13:45:58,175 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# ...

# %%
for car in session.query(Cars):
  print(car.__dict__)
# Out:
# 2025-02-18 13:45:58,908 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:45:58,910 INFO sqlalchemy.engine.Engine SELECT cars.car_id AS cars_car_id, cars.producer AS cars_producer, cars.model AS cars_model, cars.year AS cars_year, cars.horse_power AS cars_horse_power, cars.price_per_day AS cars_price_per_day
# FROM cars
# INFO:sqlalchemy.engine.Engine:SELECT cars.car_id AS cars_car_id, cars.producer AS cars_producer, cars.model AS cars_model, cars.year AS cars_year, cars.horse_power AS cars_horse_power, cars.price_per_day AS cars_price_per_day
# FROM cars
# 2025-02-18 13:45:58,912 INFO sqlalchemy.engine.Engine [cached since 95.07s ago] {}
# INFO:sqlalchemy.engine.Engine:[cached since 95.07s ago] {}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7bb838103d70>, 'horse_power': 80, 'model': 'Leon', 'year': 2016, 'car_id': 1, 'producer': 'Seat', 'price_per_day': 200}
# ...

# %%
bookings = [
{'client_id': 3, 'car_id': 3, 'start_date': '2020-07-06', 'end_date': '2020-07-08', 'total_amount': 400},
{'client_id': 6, 'car_id': 10, 'start_date': '2020-07-10', 'end_date': '2020-07-16', 'total_amount': 1680},
{'client_id': 4, 'car_id': 5, 'start_date': '2020-07-11', 'end_date': '2020-07-14', 'total_amount': 450},
{'client_id': 5, 'car_id': 4, 'start_date': '2020-07-11', 'end_date': '2020-07-13', 'total_amount': 600},
{'client_id': 7, 'car_id': 3, 'start_date': '2020-07-12', 'end_date': '2020-07-14', 'total_amount': 800},
{'client_id': 5, 'car_id': 7, 'start_date': '2020-07-14', 'end_date': '2020-07-17', 'total_amount': 240},
{'client_id': 3, 'car_id': 8, 'start_date': '2020-07-14', 'end_date': '2020-07-16', 'total_amount': 380},
{'client_id': 5, 'car_id': 9, 'start_date': '2020-07-15', 'end_date': '2020-07-18', 'total_amount': 1080},
{'client_id': 6, 'car_id': 10, 'start_date': '2020-07-16', 'end_date': '2020-07-20', 'total_amount': 1120},
{'client_id': 8, 'car_id': 1, 'start_date': '2020-07-16', 'end_date': '2020-07-19', 'total_amount': 600},
{'client_id': 9, 'car_id': 2, 'start_date': '2020-07-16', 'end_date': '2020-07-21', 'total_amount': 500},
{'client_id': 10, 'car_id': 6, 'start_date': '2020-07-17', 'end_date': '2020-07-19', 'total_amount': 280},
{'client_id': 1, 'car_id': 9, 'start_date': '2020-07-17', 'end_date': '2020-07-19', 'total_amount': 720},
{'client_id': 3, 'car_id': 7, 'start_date': '2020-07-18', 'end_date': '2020-07-21', 'total_amount': 240},
{'client_id': 5, 'car_id': 4, 'start_date': '2020-07-18', 'end_date': '2020-07-22', 'total_amount': 1200}]

# %% [markdown]
# ### Pandas a SQLAlchemy

# %%
import pandas as pd
df_bookings = []
for element in bookings:
  df_tmp=pd.DataFrame(element, index=[0])
  df_bookings.append(df_tmp)

# %%
df_bookings = pd.concat(df_bookings).reset_index(drop=True)

# %%
df_bookings
# Out:
#     client_id  car_id  start_date    end_date  total_amount
# 0           3       3  2020-07-06  2020-07-08           400
# 1           6      10  2020-07-10  2020-07-16          1680
# 2           4       5  2020-07-11  2020-07-14           450
# 3           5       4  2020-07-11  2020-07-13           600
# 4           7       3  2020-07-12  2020-07-14           800
# 5           5       7  2020-07-14  2020-07-17           240
# 6           3       8  2020-07-14  2020-07-16           380
# 7           5       9  2020-07-15  2020-07-18          1080
# 8           6      10  2020-07-16  2020-07-20          1120
# 9           8       1  2020-07-16  2020-07-19           600
# 10          9       2  2020-07-16  2020-07-21           500
# 11         10       6  2020-07-17  2020-07-19           280
# 12          1       9  2020-07-17  2020-07-19           720
# 13          3       7  2020-07-18  2020-07-21           240
# 14          5       4  2020-07-18  2020-07-22          1200

# %%
# zapis do databaze pomoci pd to SQL
df_bookings.to_sql(name="bookings", con=engine_db_cars, if_exists="replace")
# Out:
# 2025-02-18 13:46:55,774 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:46:55,778 INFO sqlalchemy.engine.Engine DESCRIBE `car_rental`.`bookings`
# INFO:sqlalchemy.engine.Engine:DESCRIBE `car_rental`.`bookings`
# 2025-02-18 13:46:55,780 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:46:55,785 INFO sqlalchemy.engine.Engine DESCRIBE `car_rental`.`bookings`
# INFO:sqlalchemy.engine.Engine:DESCRIBE `car_rental`.`bookings`
# 2025-02-18 13:46:55,787 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:46:55,790 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `car_rental`
# INFO:sqlalchemy.engine.Engine:SHOW FULL TABLES FROM `car_rental`
# 2025-02-18 13:46:55,791 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# ...

# %%
# cteni z databaze pomoci pd read sql
pd.read_sql(sql="SELECT * FROM bookings", con=engine_db_cars)
# Out:
# 2025-02-18 13:47:43,011 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-02-18 13:47:43,013 INFO sqlalchemy.engine.Engine DESCRIBE `car_rental`.`SELECT * FROM bookings`
# INFO:sqlalchemy.engine.Engine:DESCRIBE `car_rental`.`SELECT * FROM bookings`
# 2025-02-18 13:47:43,014 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:47:43,018 INFO sqlalchemy.engine.Engine SELECT * FROM bookings
# INFO:sqlalchemy.engine.Engine:SELECT * FROM bookings
# 2025-02-18 13:47:43,020 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2025-02-18 13:47:43,025 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
#     index  client_id  car_id  start_date    end_date  total_amount
# 0       0          3       3  2020-07-06  2020-07-08           400
# 1       1          6      10  2020-07-10  2020-07-16          1680
# ...

# %% [markdown]
# ### Úkol 10
# 1. Vypište všechny rezervace zákazníka s id = 3. Vyzkoušejte
# query() i select().
# 2. Vypište všechna auta zapůjčená zákazníkem s id = 5.
# Vyzkoušejte query() i select().

# %%
res = session.query(Cars).filter(Cars.producer == "Seat")

# %%
for element in res:
  print((element.__dict__))
# Out:
# 2025-02-18 13:47:55,944 INFO sqlalchemy.engine.Engine SELECT cars.car_id AS cars_car_id, cars.producer AS cars_producer, cars.model AS cars_model, cars.year AS cars_year, cars.horse_power AS cars_horse_power, cars.price_per_day AS cars_price_per_day
# FROM cars
# WHERE cars.producer = %(producer_1)s
# INFO:sqlalchemy.engine.Engine:SELECT cars.car_id AS cars_car_id, cars.producer AS cars_producer, cars.model AS cars_model, cars.year AS cars_year, cars.horse_power AS cars_horse_power, cars.price_per_day AS cars_price_per_day
# FROM cars
# WHERE cars.producer = %(producer_1)s
# 2025-02-18 13:47:55,947 INFO sqlalchemy.engine.Engine [generated in 0.00268s] {'producer_1': 'Seat'}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00268s] {'producer_1': 'Seat'}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7bb838103d70>, 'horse_power': 80, 'model': 'Leon', 'year': 2016, 'car_id': 1, 'producer': 'Seat', 'price_per_day': 200}
# ...

# %%
from sqlalchemy import join

# %%
j = join(Bookings, Cars, Bookings.car_id == Cars.car_id)

# %% [markdown]
# ## Serializace

# %%
grades = { 'Alice': 89, 'Bob': 72, 'Charles': 87 }

# %%
import pickle
serial_grades = pickle.dumps(grades)

# %%
print(serial_grades)
# Out:
# b'\x80\x04\x95#\x00\x00\x00\x00\x00\x00\x00}\x94(\x8c\x05Alice\x94KY\x8c\x03Bob\x94KH\x8c\x07Charles\x94KWu.'

# %%
df_bk_pkl = pickle.dumps(df_bookings)

# %%
df_bookings
# Out:
#     client_id  car_id  start_date    end_date  total_amount
# 0           3       3  2020-07-06  2020-07-08           400
# 1           6      10  2020-07-10  2020-07-16          1680
# 2           4       5  2020-07-11  2020-07-14           450
# 3           5       4  2020-07-11  2020-07-13           600
# 4           7       3  2020-07-12  2020-07-14           800
# 5           5       7  2020-07-14  2020-07-17           240
# 6           3       8  2020-07-14  2020-07-16           380
# 7           5       9  2020-07-15  2020-07-18          1080
# 8           6      10  2020-07-16  2020-07-20          1120
# 9           8       1  2020-07-16  2020-07-19           600
# 10          9       2  2020-07-16  2020-07-21           500
# 11         10       6  2020-07-17  2020-07-19           280
# 12          1       9  2020-07-17  2020-07-19           720
# 13          3       7  2020-07-18  2020-07-21           240
# 14          5       4  2020-07-18  2020-07-22          1200

# %%
print(df_bk_pkl)
# Out:
# b'\x80\x04\x95f\x05\x00\x00\x00\x00\x00\x00\x8c\x11pandas.core.frame\x94\x8c\tDataFrame\x94\x93\x94)\x81\x94}\x94(\x8c\x04_mgr\x94\x8c\x1epandas.core.internals.managers\x94\x8c\x0cBlockManager\x94\x93\x94\x8c\x16pandas._libs.internals\x94\x8c\x0f_unpickle_block\x94\x93\x94\x8c\x15numpy.core.multiarray\x94\x8c\x0c_reconstruct\x94\x93\x94\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94K\x00\x85\x94C\x01b\x94\x87\x94R\x94(K\x01K\x03K\x0f\x86\x94h\x0f\x8c\x05dtype\x94\x93\x94\x8c\x02i8\x94\x89\x88\x87\x94R\x94(K\x03\x8c\x01<\x94NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00t\x94b\x89Bh\t\x00\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x
# ...

# %% [markdown]
# ## Ydata (Pandas) Profiling

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 114.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 100.3 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=5dacad04819946148efdaab9d9e345ed90192f26f89ca2e58d2106977c694661
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df=df_bookings, title = "Booking df report")

# %%
profile.to_widgets()
# Out:
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/profile_report.py:528: UserWarning: Ipywidgets is not yet fully supported on Google Colab (https://github.com/googlecolab/colabtools/issues/60).As an alternative, you can use the HTML report. See the documentation for more information.
#   warnings.warn(
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## API

# %%
import requests
url = "https://api.openweathermap.org/data/2.5/forecast?q=Wrocław&appid=XXX&units=metric"
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [401]>

# %%
print(response) # will display the status
# will display the status and perhaps the error code
print(f"The request returned {response.status_code} : {response.reason}'")
# read the data from response (parsing as json)
payload = response.json()
# Out:
# <Response [401]>
# The request returned 401 : Unauthorized'

# %%
# !pip install yahoo-fin
# !pip install requests-html
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.1/201.1 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 69.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 8.1 MB/s eta 0:00:00
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=eb381b3873b9a7c2acabe353df00f732b3ef4eea9bbf0476e674da0bf768eb0b
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.2
# ...

# %%
import yahoo_fin.stock_info as yh
# Out:
# Warning - Certain functionality
#              requires requests_html, which is not installed.
#
#              Install using:
#              pip install requests_html
#
#              After installation, you may have to restart your Python session.

# %%
# !pip install requests_html

# %%
# !pip install yahoofinance

# %%
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 34.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 6.7 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.17.9-cp311-cp311-linux_x86_64.whl size=886607 sha256=8ad2fe0fe5d0f711600b29955b10b6f8520a783624801395b95c784c78c2967f
#   Stored in directory: /root/.cache/pip/wheels/f4/14/e4/50c88c865833085aeb91e2bd40e3a683ff434806386b8ee7bc
# Successfully built peewee
# ...

# %%
import yfinance as yahooFinance
GetFacebookInformation = yahooFinance.Ticker("META")

# %%
GetFacebookInformation.info['sector']
# Out:
# 'Communication Services'

# %%
GetFacebookInformation.__dict__
# Out:
# {'ticker': 'META',
#  'proxy': None,
#  'session': None,
#  '_tz': None,
#  '_isin': None,
#  '_news': [],
#  '_shares': None,
#  '_earnings_dates': {},
#  '_earnings': None,
#  '_financials': None,
#  '_data': <yfinance.data.YfData at 0x7bb755328690>,
#  '_price_history': None,
#  '_analysis': <yfinance.scrapers.analysis.Analysis at 0x7bb755ba3ed0>,
#  '_holders': <yfinance.scrapers.holders.Holders at 0x7bb755463a90>,
#  '_quote': <yfinance.scrapers.quote.Quote at 0x7bb755bd7310>,
#  '_fundamentals': <yfinance.scrapers.fundamentals.Fundamentals at 0x7bb755ba2590>,
#  '_funds_data': None,
#  '_fast_info': None,
#  '_expirations': {},
#  '_underlying': {}}

# %%
response = yh.get_data('nflx', start_date = '01/09/2020', end_date = '30/09/2020',
index_as_date = True, interval = '1wk')

# %%
print("Average value of open: ", response.open.mean())
print("Average highest daily value: ", response.high.mean())
print("Average lowest daily value: ", response.low.mean())
# print("Percentage increase in the company's shares: ",(response.open[-1]-response.open[0] * 100, "%")
# Out:
# Average value of open:  422.29384358723956
# Average highest daily value:  445.1335903069912
# Average lowest daily value:  407.9005134778145
